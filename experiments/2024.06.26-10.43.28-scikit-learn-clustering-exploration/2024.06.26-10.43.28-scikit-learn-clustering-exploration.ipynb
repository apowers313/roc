# %% [markdown]
# __[scikit learn clustering exploration](https://github.com/apowers313/roc/blob/master/experiments/2024.06.26-10.43.28-scikit-learn-clustering-exploration.ipynb)__

# %%
# !date
# Out:
# Wed Jun 26 10:52:26 PDT 2024

# %%
# https://scikit-learn.org/stable/auto_examples/cluster/plot_dbscan.html

from sklearn.datasets import make_blobs

centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4, random_state=0)

# %%
for ln in X:
    print(ln)
# Out:
# [0.84022039 1.14802236]
# [-1.15474834 -1.2041171 ]
# [0.67863613 0.72418009]
# [ 0.45078298 -1.4270968 ]
# [1.49211627 1.48095194]
# [-0.98194639 -0.06415008]
# [-1.02343462 -1.12701724]
# [ 0.93511262 -0.69222793]
# [1.45065437 0.5680274 ]
# [1.37976832 1.0350205 ]
# [-0.93442857 -0.96147146]
# [-0.97016544 -1.43083963]
# [-0.76404807 -1.14554352]
# [ 1.5234675  -1.01031942]
# [-0.4856064  -1.60279936]
# [0.53752703 1.31247924]
# [-1.1569556  -2.21845722]
# [-0.62363295 -0.83791837]
# [-0.19784514 -0.64762498]
# [ 0.78020058 -1.43942829]
# [ 0.81300273 -1.34499732]
# [ 0.86937561 -1.00328395]
# [ 1.30833478 -0.90273271]
# [ 1.30966424 -1.30978359]
# [-1.11057314 -1.10383079]
# [-0.87005215 -0.60115281]
# [ 0.83950612 -1.32003299]
# [1.24563175 1.36888267]
# [0.58630286 1.27263781]
# [ 1.394127   -0.69323213]
# [0.82363095 0.8878578 ]
# [-0.91046257 -0.86815081]
# [-1.60095863 -1.71106678]
# [0.87537899 1.02246614]
# [-0.62542171 -1.01403807]
# [1.11217668 0.60275056]
# ...

# %%
print(type(X))
print(X[:, 1])
# Out:
# <class 'numpy.ndarray'>
# [ 1.14802236 -1.2041171   0.72418009 -1.4270968   1.48095194 -0.06415008
#  -1.12701724 -0.69222793  0.5680274   1.0350205  -0.96147146 -1.43083963
#  -1.14554352 -1.01031942 -1.60279936  1.31247924 -2.21845722 -0.83791837
#  -0.64762498 -1.43942829 -1.34499732 -1.00328395 -0.90273271 -1.30978359
#  -1.10383079 -0.60115281 -1.32003299  1.36888267  1.27263781 -0.69323213
#   0.8878578  -0.86815081 -1.71106678  1.02246614 -1.01403807  0.60275056
#  -0.83812182  1.48897803  0.94014618 -0.43785382 -0.64301045 -0.99540044
#  -1.08669259 -1.47387464 -0.99186633 -0.83094855  0.71610881 -0.6150633
#   1.77181282 -0.903685   -0.69836173 -0.8474335  -0.27091056 -0.92967242
#  -0.93414248 -0.96871553 -0.41147122  1.36241786 -1.0123745  -1.14792047
#  -0.94492407 -0.58036272 -0.73469676 -1.2246315  -1.13921855  0.70313399
#  -0.58337264 -1.29332512  1.38775868  0.8790789   0.79430641 -1.28452254
#   1.61720584  0.95584428 -0.78752865 -0.75324538  1.82579714 -0.14713864
# ...

# %% [markdown]
# Clustering assumes points, not a grid of heights
#
# Let's try local maxima instead?

# %%
import numpy as np

img = np.random.normal(size=(100, 256, 256))
# print(img)
print(img[0][0])
# Out:
# [-1.36190063e+00  5.82647854e-02 -8.74034467e-01 -1.67469958e+00
#   5.36150407e-01  7.74754063e-01  9.74507897e-01 -2.67127110e-01
#  -9.66985124e-02  1.56916868e-01  1.99808165e+00  1.98398994e-01
#  -1.42694694e+00 -2.09954764e+00 -1.36492599e+00 -6.55662947e-01
#   4.21740612e-01  1.43966621e-01 -1.31861728e+00 -3.01635392e-01
#   4.17690440e-01 -1.97083864e+00 -1.79895561e-01  1.28922594e-01
#  -1.07624233e+00 -1.16809791e+00  6.60771196e-01 -9.70603758e-01
#  -8.25259640e-01 -5.90762835e-01 -1.87279125e+00 -3.93863390e-01
#   4.57538664e-01  1.15441136e+00 -3.42936431e-01  7.63928109e-01
#  -1.21611987e+00  1.23971930e+00 -4.29195006e-01 -2.07010981e+00
#   1.39601500e+00 -8.00375901e-01 -3.10837489e-01 -5.23746650e-02
#  -1.66117479e+00  3.34807794e-01  4.53621984e-01  7.99525158e-01
#  -1.64138173e+00  4.14819330e-01 -8.62280545e-01 -1.04228249e+00
#   4.74084972e-01 -4.38297082e-01  5.42919948e-01 -9.19975243e-01
# ...
