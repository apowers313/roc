# %% [markdown]
# "__[test](https://github.com/apowers313/roc/blob/master/experiments/2025.02.28-15.44.39-test/2025.02.28-15.44.39-test.py)__"

# %%
import marimo as mo

# %%
mo.__version__

# %%
print("hi", mo.__version__)

# %%
import os

print(os.getcwd())

# %%
import sys

sys.path.append("/home/apowers/Projects/roc")

# %%
print(sys.path)
# Out:
# ['/home/apowers/Projects/roc/experiments/2025.02.28-15.44.39-test', '/usr/local/bin', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '/home/apowers/.local/lib/python3.10/site-packages', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/home/apowers/Projects/roc']

# %%
# Out:
# <span class="codehilite"><div class="highlight"><pre><span></span><span class="gt">Traceback (most recent call last):</span>
#   File <span class="nb">&quot;/usr/local/lib/python3.10/dist-packages/marimo/_runtime/executor.py&quot;</span>, line <span class="m">141</span>, in <span class="n">execute_cell</span>
# <span class="w">    </span><span class="n">exec</span><span class="p">(</span><span class="n">cell</span><span class="o">.</span><span class="n">body</span><span class="p">,</span> <span class="n">glbls</span><span class="p">)</span>
#   File <span class="nb">&quot;/tmp/marimo_627/__marimo__cell_SFPL_.py&quot;</span>, line <span class="m">1</span>, in <span class="n">&lt;module&gt;</span>
# <span class="w">    </span><span class="kn">import</span> <span class="nn">roc</span>
#   File <span class="nb">&quot;/home/apowers/Projects/roc/roc/__init__.py&quot;</span>, line <span class="m">9</span>, in <span class="n">&lt;module&gt;</span>
# <span class="w">    </span><span class="kn">import</span> <span class="nn">roc.feature_extractors</span>
#   File <span class="nb">&quot;/home/apowers/Projects/roc/roc/feature_extractors/__init__.py&quot;</span>, line <span class="m">1</span>, in <span class="n">&lt;module&gt;</span>
# <span class="w">    </span><span class="kn">import</span> <span class="nn">roc.feature_extractors.color</span> <span class="k">as</span> <span class="nn">color</span>
#   File <span class="nb">&quot;/home/apowers/Projects/roc/roc/feature_extractors/color.py&quot;</span>, line <span class="m">5</span>, in <span class="n">&lt;module&gt;</span>
# <span class="w">    </span><span class="kn">from</span> <span class="nn">..location</span> <span class="kn">import</span> <span class="n">Point</span>
#   File <span class="nb">&quot;/home/apowers/Projects/roc/roc/location.py&quot;</span>, line <span class="m">5</span>, in <span class="n">&lt;module&gt;</span>
# <span class="w">    </span><span class="kn">from</span> <span class="nn">typing</span> <span class="kn">import</span> <span class="n">Any</span><span class="p">,</span> <span class="n">Generic</span><span class="p">,</span> <span class="n">Iterator</span><span class="p">,</span> <span class="n">NewType</span><span class="p">,</span> <span class="n">Self</span><span class="p">,</span> <span class="n">TypeVar</span><span class="p">,</span> <span class="n">cast</span><span class="p">,</span> <span class="n">overload</span>
# <span class="gr">ImportError</span>: <span class="n">cannot import name &#39;Self&#39; from &#39;typing&#39; (/usr/lib/python3.10/typing.py)</span>
# </pre></div>
# </span>
