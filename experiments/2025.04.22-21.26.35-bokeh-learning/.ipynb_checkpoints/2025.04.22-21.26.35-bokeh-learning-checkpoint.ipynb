# %% [markdown]
# __[bokeh learning](https://github.com/apowers313/roc/blob/master/experiments/2025.04.22-21.26.35-bokeh-learning/2025.04.22-21.26.35-bokeh-learning.ipynb)__

# %%
# !date

# %%
# save notebook path before we get started
import os

notebook_path = os.path.abspath("")  # not sure if this or os.getcwd() is more reliable

# %% [markdown]
# # Hello World

# %%
from bokeh.plotting import figure, show

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# create a new plot with a title and axis labels
p = figure(title="Simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness to the plot
p.line(x, y, legend_label="Temp.", line_width=2)

# show the results
show(p)
